# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import StandardScaler

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.utils import shuffle

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Cough_dataframe = pd.read_csv("./cough.csv")

# %%
file1 = open('./SETS/set_1.txt', 'r') 
Lines = file1.readlines() 
  
count = 0
# Strips the newline character 
# for line in Lines: 
#     print("Line{}: {}".format(count, line.strip())) 

set_1_cough_dataframe = pd.DataFrame()
for i, line in enumerate(Lines):
    A = Cough_dataframe[(Cough_dataframe['217'] == (Lines[i].strip()+".mat"))]
    set_1_cough_dataframe = pd.DataFrame.append(set_1_cough_dataframe,A)

# %%
set_1_cough_dataframe
# Out:
#             0         1         2         3         4         5         6  \
# 767  3.286010 -0.909947  1.510621 -0.615138  0.800149  0.013212  0.210776
# 768  3.113335 -0.983309  1.981002  0.101239  1.076818  0.207318  0.044185
# 769  2.875563 -1.050045  1.094977 -0.847974  0.514331  0.035478 -0.188381
# 770  3.615480 -0.515167  1.656723 -0.274974  0.767951  0.071123 -0.101178
# 771  3.516295 -0.793678  1.228817 -0.672577  0.544759  0.117527 -0.030195
# ..        ...       ...       ...       ...       ...       ...       ...
# 830  0.545927 -1.039497 -1.200010 -0.314233  0.059715 -1.223173 -0.193569
# 831  0.672521 -1.007432  0.137572 -0.435003  0.187037 -1.219323 -0.500791
# 832 -1.303156 -1.936709 -0.702747 -0.348895 -0.150715 -0.589730 -0.212648
# 833  0.231333 -1.340913  0.237875 -0.416223 -0.319331 -1.096406 -0.758328
# 834 -0.519031 -1.490952 -0.247252 -0.720354 -0.244377 -0.764787 -0.462910
#
#             7         8         9  ...       208       209       210  \
# ...

# %%
file2 = open('./SETS/set_2.txt', 'r') 
Lines = file2.readlines() 
  
count = 0
# Strips the newline character 
# for line in Lines: 
#     print("Line{}: {}".format(count, line.strip())) 

set_2_cough_dataframe = pd.DataFrame()
for i, line in enumerate(Lines):
    A = Cough_dataframe[(Cough_dataframe['217'] == (Lines[i].strip()+".mat"))]
    set_2_cough_dataframe = pd.DataFrame.append(set_2_cough_dataframe,A)

# %%
file3 = open('./SETS/set_3.txt', 'r') 
Lines = file3.readlines() 
  
count = 0
# Strips the newline character 
# for line in Lines: 
#     print("Line{}: {}".format(count, line.strip())) 

set_3_cough_dataframe = pd.DataFrame()
for i, line in enumerate(Lines):
    A = Cough_dataframe[(Cough_dataframe['217'] == (Lines[i].strip()+".mat"))]
    set_3_cough_dataframe = pd.DataFrame.append(set_3_cough_dataframe,A)

# %%
file4 = open('./SETS/set_4.txt', 'r') 
Lines = file4.readlines() 
  
count = 0
# Strips the newline character 
# for line in Lines: 
#     print("Line{}: {}".format(count, line.strip())) 

set_4_cough_dataframe = pd.DataFrame()
for i, line in enumerate(Lines):
    A = Cough_dataframe[(Cough_dataframe['217'] == (Lines[i].strip()+".mat"))]
    set_4_cough_dataframe = pd.DataFrame.append(set_4_cough_dataframe,A)

# %%
file5 = open('./SETS/set_5.txt', 'r') 
Lines = file5.readlines() 
  
count = 0
# Strips the newline character 
# for line in Lines: 
#     print("Line{}: {}".format(count, line.strip())) 

set_5_cough_dataframe = pd.DataFrame()
for i, line in enumerate(Lines):
    A = Cough_dataframe[(Cough_dataframe['217'] == (Lines[i].strip()+".mat"))]
    set_5_cough_dataframe = pd.DataFrame.append(set_5_cough_dataframe,A)

# %%
big = [set_1_cough_dataframe,set_2_cough_dataframe,set_3_cough_dataframe,set_4_cough_dataframe,set_5_cough_dataframe]

# %%
Cough_dataframe
# Out:
#             0         1         2         3         4         5         6  \
# 0   -1.049566 -0.724346 -0.643932 -1.312013  0.753689 -0.749393  0.948658
# 1   -0.061991 -0.409625 -0.595233 -1.286315  0.849574 -0.234460  1.107897
# 2    0.507403  0.534974  0.407169 -0.947500  0.590494 -0.218818  0.849918
# 3    0.433352 -0.859231  0.815786  0.382931  1.386598  0.363840  1.678211
# 4    0.332375 -2.898388  1.046713  1.091744  1.408277  0.348940  1.828713
# ..        ...       ...       ...       ...       ...       ...       ...
# 840  1.835401  0.529570  0.330576 -1.120103  0.626476 -0.803817 -0.086557
# 841  2.416199  0.452534  0.785539 -1.249049  0.534740 -0.331307 -0.496778
# 842  2.287450 -0.082048  0.832924 -0.909144  0.589334 -0.655185 -0.295484
# 843  2.048181  0.307535  1.132548 -0.721434  0.823586 -0.429068 -0.100065
# 844  2.476692  0.011225  0.711328 -0.634662  0.897903 -0.907065 -0.056001
#
#             7         8         9  ...       208       209       210  \
# ...

# %%
fold_1 = shuffle(pd.concat(big[:4]))
test_1 = shuffle(big[4])
fold_2 = shuffle(pd.concat(big[1:5]))
test_2 = shuffle(big[0])
fold_3 = shuffle(pd.concat([big[0],big[2],big[3],big[4]]))
test_3 = shuffle(big[1])
fold_4 = shuffle(pd.concat([big[0],big[1],big[3],big[4]]))
test_4 = shuffle(big[2])
fold_5 = shuffle(pd.concat([big[0],big[2],big[1],big[4]]))
test_5 = shuffle(big[3])

# %%
test_1
# Out:
#             0         1         2         3         4         5         6  \
# 605  1.125106 -1.068828  0.892897 -0.830312  0.742419  0.367419 -0.145262
# 143  0.745353  0.880866  1.279933 -0.602485  2.250076  0.664349  1.205670
# 163  0.120188 -0.141800  0.336768 -2.617581  0.266877 -0.112183 -0.898816
# 448  1.337057  1.326073  1.535153  0.647805  1.343794  0.346755  0.782265
# 503  2.420429 -0.165250  0.187798 -0.283426 -0.076208 -0.122334  0.597736
# ..        ...       ...       ...       ...       ...       ...       ...
# 504  1.790240 -0.814077  0.419106 -0.678109 -0.387009 -0.068300  0.336641
# 680  3.900003  1.278252  0.491424 -0.787334  1.079528 -0.361900  0.011536
# 695  0.149137 -1.880894  1.919741 -0.071526  1.488882  0.041203  0.029368
# 44   3.041008  0.824296  0.969566 -0.684075  1.148084  0.047527 -0.148946
# 751  0.935606 -0.124231  1.455567  0.366048  1.026677 -0.176731  0.218001
#
#             7         8         9  ...       208       209       210  \
# ...

# %%
list_1 = []

# %%
X_train = fold_1.iloc[:,:216]
y_train = fold_1.iloc[:,216]
X_test = test_1.iloc[:,:216]
y_test = test_1.iloc[:,216]


scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)



### SVM

svm = SVC()

svm.fit(X_train,y_train)

list_1.append(accuracy_score(y_test,svm.predict(X_test)))

accuracy_score(y_train,svm.predict(X_train))
# Out:
# 0.9927113702623906

# %%
list_1
# Out:
# [0.6352201257861635]

# %%
X_train = fold_2.iloc[:,:216]
y_train = fold_2.iloc[:,216]
X_test = test_2.iloc[:,:216]
y_test = test_2.iloc[:,216]


scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)



### SVM

svm = SVC()

svm.fit(X_train,y_train)

list_1.append(accuracy_score(y_test,svm.predict(X_test)))

accuracy_score(y_train,svm.predict(X_train))
# Out:
# 0.9881129271916791

# %%
X_train = fold_3.iloc[:,:216]
y_train = fold_3.iloc[:,216]
X_test = test_3.iloc[:,:216]
y_test = test_3.iloc[:,216]


scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)



### SVM

svm = SVC()

svm.fit(X_train,y_train)

list_1.append(accuracy_score(y_test,svm.predict(X_test)))

accuracy_score(y_train,svm.predict(X_train))
# Out:
# 0.9859594383775351

# %%
X_train = fold_4.iloc[:,:216]
y_train = fold_4.iloc[:,216]
X_test = test_4.iloc[:,:216]
y_test = test_4.iloc[:,216]


scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)



### SVM

svm = SVC()

svm.fit(X_train,y_train)

list_1.append(accuracy_score(y_test,svm.predict(X_test)))

accuracy_score(y_train,svm.predict(X_train))
# Out:
# 0.9911764705882353

# %%
X_train = fold_5.iloc[:,:216]
y_train = fold_5.iloc[:,216]
X_test = test_5.iloc[:,:216]
y_test = test_5.iloc[:,216]


scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)



### SVM

svm = SVC()

svm.fit(X_train,y_train)

list_1.append(accuracy_score(y_test,svm.predict(X_test)))

accuracy_score(y_train,svm.predict(X_train))
# Out:
# 0.9842857142857143

# %%
np.array(list_1).mean()
# Out:
# 0.6297472258513763

# %%
# X = pd.concat([fold_1,train_1]).iloc[:,:216]
# y = pd.concat([fold_1,train_1]).iloc[:,216]

# %%
X_train = fold_1.iloc[:,:72]
y_train = fold_1.iloc[:,216]

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
C_range = np.logspace(-1, 10, 12)
gamma_range = np.logspace(-1, 20, 22)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits=5)
grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cv, verbose=3, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 264 candidates, totalling 1320 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 1136 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 1320 out of 1320 | elapsed:   28.3s finished
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=5, random_state=None, test_size='default',
#             train_size=None),
#        error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
# ...

# %%
grid.best_params_
# Out:
# {'C': 10.0, 'gamma': 1.0}

# %%
y_pred = grid.predict(test_1.iloc[:,:72])

accuracy_score(test_1.iloc[:,216],y_pred)

# %%
accuracy_score(y_train,grid.predict(X_train))
# Out:
# 1.0

# %%
test_1
# Out:
#             0         1         2         3         4         5         6  \
# 605  1.125106 -1.068828  0.892897 -0.830312  0.742419  0.367419 -0.145262
# 143  0.745353  0.880866  1.279933 -0.602485  2.250076  0.664349  1.205670
# 163  0.120188 -0.141800  0.336768 -2.617581  0.266877 -0.112183 -0.898816
# 448  1.337057  1.326073  1.535153  0.647805  1.343794  0.346755  0.782265
# 503  2.420429 -0.165250  0.187798 -0.283426 -0.076208 -0.122334  0.597736
# ..        ...       ...       ...       ...       ...       ...       ...
# 504  1.790240 -0.814077  0.419106 -0.678109 -0.387009 -0.068300  0.336641
# 680  3.900003  1.278252  0.491424 -0.787334  1.079528 -0.361900  0.011536
# 695  0.149137 -1.880894  1.919741 -0.071526  1.488882  0.041203  0.029368
# 44   3.041008  0.824296  0.969566 -0.684075  1.148084  0.047527 -0.148946
# 751  0.935606 -0.124231  1.455567  0.366048  1.026677 -0.176731  0.218001
#
#             7         8         9  ...       208       209       210  \
# ...

# %%
from libsvm.svmutil import *

# %%
prob = svm_problem(y_train.values,X_train.values)

# %%
param = svm_parameter('-v 5 -t 2 -c 10 -g 0.1 -b 1')

# %%
m = libsvm.svm_train(prob, param)

# %%
p_label, p_acc, p_val = svm_predict(y_train.values,X_train.values, m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-169a0054ea35> in <module>
# ----> 1 p_label, p_acc, p_val = svm_predict(y_train.values,X_train.values, m)
#
# ~/anaconda3/lib/python3.7/site-packages/libsvm/svmutil.py in svm_predict(y, x, m, options)
#     191                 i+=1
#     192
# --> 193         svm_type = m.get_svm_type()
#     194         is_prob_model = m.is_probability_model()
#     195         nr_class = m.get_nr_class()
#
# AttributeError: 'LP_svm_model' object has no attribute 'get_svm_type'

# %%
type(test_1.iloc[:,:72].values)
# Out:
# numpy.ndarray

# %%
svm_save_model('cough_72.model', m)

# %%
m = svm_load_model('cough_72.model')

# %%
p_label, p_acc, p_val = svm_predict(y_train.values, X_train.values, m, '-b 0')
# Out:
# Model supports probability estimates, but disabled in predicton.
# Accuracy = 98.8338% (678/686) (classification)

# %%
p_label, p_acc, p_val = svm_predict(test_1.iloc[:,216].values,test_1.iloc[:,:72].values, m, '-b 1')
# Out:
# Accuracy = 63.522% (101/159) (classification)

# %%
A[str(42)] = 45

# %%
np.savetxt("out_[0].csv", test_1.iloc[:,:72].values[1], delimiter=" ", fmt="%f")
